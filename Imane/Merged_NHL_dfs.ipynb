# %%
import pandas as pd

# %%
file1 = "injNHLdata18.csv"

file2 = "NHLBodstat_18.csv"

# file6 = "NHLTimeonIce_18.csv"

file3 = "injCount18.csv"


NHLInjCnt = pd.read_csv(file3)
NHLBodstat = pd.read_csv(file2)
NHLInj = pd.read_csv(file1)

# %%
NHLInj = NHLInj.drop(['Unnamed: 0', 'CAP HIT', 'CHIP', 'POSITION', 'SEASON'], axis=1)
NHLInj.head()
# Out:
#    GAMES MISSED INJURY TYPE          PLAYER     TEAM
# 0            14  Lower body  Comtois Maxime  Anaheim
# 1            33        Ribs   Eaves Patrick  Anaheim
# 2            13    Shoulder   Eaves Patrick  Anaheim
# 3             5       Groin    Getzlaf Ryan  Anaheim
# 4             1  Upper body    Getzlaf Ryan  Anaheim

# %%
NHLInjCnt.head()
# Out:
#    Unnamed: 0             PLAYER  INJURY COUNT  CAP HIT        CHIP  \
# 0           0  Abdelkader Justin             1     4.25  570.121951
# 1           1       Aberg Pontus             1     0.65   63.414634
# 2           2  Andersen Frederik             2     5.00  365.853659
# 3           3  Andersen Frederik             2     5.00   60.975610
# 4           4     Anderson Craig             2     4.75  637.195122
#
#    GAMES MISSED INJURY TYPE POSITION   SEASON       TEAM
# 0            11         Leg        F  2018/19    Detroit
# 1             8  Lower body        F  2018/19  Minnesota
# 2             6       Groin        G  2018/19    Toronto
# 3             1        Knee        G  2018/19    Toronto
# 4            11  Concussion        G  2018/19     Ottawa

# %%
NHLInjCnt = NHLInjCnt.drop(['Unnamed: 0', 'CAP HIT', 'CHIP', 'POSITION', 'SEASON'], axis=1)
NHLInjCnt.head()
# Out:
#               PLAYER  INJURY COUNT  GAMES MISSED INJURY TYPE       TEAM
# 0  Abdelkader Justin             1            11         Leg    Detroit
# 1       Aberg Pontus             1             8  Lower body  Minnesota
# 2  Andersen Frederik             2             6       Groin    Toronto
# 3  Andersen Frederik             2             1        Knee    Toronto
# 4     Anderson Craig             2            11  Concussion     Ottawa

# %%
NHLBodstat.head()
# Out:
#    Unnamed: 0 TEAM POSITION HEIGHT  WEIGHT   BIRTHDATE             PLAYER  AGE
# 0           1  DET       LW   6'2"     214   2/25/1987  Abdelkader Justin   32
# 1           2  MIN       LW  5'11"     196   9/23/1993       Aberg Pontus   25
# 2           3  OTT       RW   5'9"     171   5/08/1998     Abramov Vitaly   21
# 3           4  BOS        C  5'10"     205  12/01/1991       Acciari Noel   27
# 4           6   NJ       LW   6'0"     199   4/30/1992     Agostino Kenny   27

# %%
NHLBodstat = NHLBodstat.drop(['Unnamed: 0', 'TEAM', 'BIRTHDATE'], axis=1)
NHLBodstat.head()
# Out:
#   POSITION HEIGHT  WEIGHT             PLAYER  AGE
# 0       LW   6'2"     214  Abdelkader Justin   32
# 1       LW  5'11"     196       Aberg Pontus   25
# 2       RW   5'9"     171     Abramov Vitaly   21
# 3        C  5'10"     205       Acciari Noel   27
# 4       LW   6'0"     199     Agostino Kenny   27

# %%
NHL_injBod=pd.merge(NHLBodstat, NHLInjCnt, left_on ='PLAYER',right_on='PLAYER',how="inner",sort=True)
# print(NHL.shape())
NHL_injBod.head()
# Out:
#   POSITION HEIGHT  WEIGHT             PLAYER  AGE  INJURY COUNT  GAMES MISSED  \
# 0       LW   6'2"     214  Abdelkader Justin   32             1            11
# 1       LW  5'11"     196       Aberg Pontus   25             1             8
# 2        G   6'4"     230  Andersen Frederik   29             2             6
# 3        G   6'4"     230  Andersen Frederik   29             2             1
# 4        G   6'2"     185     Anderson Craig   38             2            11
#
#   INJURY TYPE       TEAM
# 0         Leg    Detroit
# 1  Lower body  Minnesota
# 2       Groin    Toronto
# 3        Knee    Toronto
# 4  Concussion     Ottawa

# %%
# write merged bodystats/Injury
NHL_injBod.to_csv('mrg_NHL_injBod18.csv', index=True, header=True)

# %%
file4 = "NHLTime.csv"


NHLTime = pd.read_csv(file4)

NHLTime.head()
# Out:
#    Unnamed: 0        PLAYER TEAM  GP   G   A  PTS  +/-     TOI/G  SHFT  \
# 0           0    Suter Ryan  MIN  82   7  40   47   -8  26:42:00  2222
# 1           1  Doughty Drew   LA  82   8  37   45  -34  26:36:00  2393
# 2           2   Letang Kris  PIT  65  16  40   56   13  25:58:00  1923
# 3           3    Jones Seth  CBJ  75   9  37   46    1  25:49:00  2214
# 4           4    Josi Roman  NSH  82  15  41   56    9  25:10:00  2359
#
#    SHFT/G      PROD POS
# 0    27.1  46:34:00   D
# 1    29.2  48:27:00   D
# 2    29.6  30:07:00   D
# 3    29.5  42:06:00   D
# 4    28.8  36:51:00   D

# %%
# Drop unecessary cols
NHLTime = NHLTime.drop(['Unnamed: 0', 'POS', 'PROD', 'TEAM'], axis=1)
NHLTime.head()
# Out:
#          PLAYER  GP   G   A  PTS  +/-     TOI/G  SHFT  SHFT/G
# 0    Suter Ryan  82   7  40   47   -8  26:42:00  2222    27.1
# 1  Doughty Drew  82   8  37   45  -34  26:36:00  2393    29.2
# 2   Letang Kris  65  16  40   56   13  25:58:00  1923    29.6
# 3    Jones Seth  75   9  37   46    1  25:49:00  2214    29.5
# 4    Josi Roman  82  15  41   56    9  25:10:00  2359    28.8

# %%
# merge time on ice with previous created merge(NHL_injBod)
NHL_alldata=pd.merge(NHLTime, NHL_injBod, left_on ='PLAYER',right_on='PLAYER',how="inner",sort=True)
# print(NHL.shape())
NHL_alldata.head()
# Out:
#               PLAYER  GP   G   A  PTS  +/-  TOI/G  SHFT  SHFT/G POSITION  \
# 0  Abdelkader Justin  71   6  13   19  -14  15:24  1465    20.6       LW
# 1       Aberg Pontus  59  12  13   25  -14  14:36  1107    18.8       LW
# 2      Anderson Joey  34   4   3    7   -7  12:54   582    17.1       RW
# 3   Andrighetto Sven  64   7  10   17   10  11:04   930    14.5       RW
# 4     Anisimov Artem  78  15  22   37   -2  16:21  1611    20.7        C
#
#   HEIGHT  WEIGHT  AGE  INJURY COUNT  GAMES MISSED INJURY TYPE        TEAM
# 0   6'2"     214   32             1            11         Leg     Detroit
# 1  5'11"     196   25             1             8  Lower body   Minnesota
# 2  5'11"     190   21             1            33       Ankle  New Jersey
# 3  5'10"     188   26             1             6  Lower body    Colorado
# 4   6'4"     198   31             1             4  Concussion     Chicago

# %%
NHL_alldata.shape
# Out:
# (597, 17)

# %%
# write final merged NHL df
NHL_alldata.to_csv('NHL_alldata.csv', index=True, header=True)
